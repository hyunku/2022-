# %%
import pandas as pd
import numpy as np
import pyproj
# 지도 시각화
import folium as g
from folium.plugins import MiniMap
from folium.plugins import MarkerCluster
import warnings
warnings.filterwarnings('ignore')
from haversine import haversine, Unit
#dbf
from dbfread import DBF
import seaborn as sns

# %%
# 파이썬 시각화 패키지 불러오기
import matplotlib.pyplot as plt
# %matplotlib inline

# 사용자 운영체제 확인
import platform
platform.system()

# 운영체제별 한글 폰트 설정
if platform.system() == 'Darwin': # Mac 환경 폰트 설정
    plt.rc('font', family='AppleGothic')
elif platform.system() == 'Windows': # Windows 환경 폰트 설정
    plt.rc('font', family='Malgun Gothic')

plt.rc('axes', unicode_minus=False) # 마이너스 폰트 설정

# 글씨 선명하게 출력하는 설정
# %config InlineBackend.figure_format = 'retina'

# %% [markdown]
# ## 보육원

# %%
child = pd.read_excel("data/서울시 보육원.xlsx")
child.head(5)
# Out:
#     연번  자치구  시설유형      시설명  아동현황(명)                  소재지         위도  \
# 0  1.0  종로구  양육시설      선덕원     47.0  종로구 세검정로 7가길 15-141  37.601670
# 1  2.0   중구  양육시설      남산원     45.0          중구 소파로2길 31  37.601670
# 2  3.0   중구  양육시설  리라아동복지관     32.0   경기도 안성시 원곡면 용소길 65        NaN
# 3  4.0  용산구  양육시설    영락보린원     55.0        용산구 후암로 4길 70  37.485192
# 4  5.0  용산구  양육시설      혜심원     56.0       용산구 소월로 2나길 18  37.553414
#
#            경도
# 0  126.950861
# 1  126.950861
# 2         NaN
# 3  127.002220
# 4  126.969173

# %%
child = child.dropna()
child.head(5)
# Out:
#     연번  자치구  시설유형    시설명  아동현황(명)                  소재지         위도          경도
# 0  1.0  종로구  양육시설    선덕원     47.0  종로구 세검정로 7가길 15-141  37.601670  126.950861
# 1  2.0   중구  양육시설    남산원     45.0          중구 소파로2길 31  37.601670  126.950861
# 3  4.0  용산구  양육시설  영락보린원     55.0        용산구 후암로 4길 70  37.485192  127.002220
# 4  5.0  용산구  양육시설    혜심원     56.0       용산구 소월로 2나길 18  37.553414  126.969173
# 5  6.0  성동구  양육시설  이든아이빌     50.0     성동구 왕십리로 21라길 11  37.560546  127.022122

# %%
child_xy = child[["위도", "경도"]]
child_xy.head(5)
# Out:
#           위도          경도
# 0  37.601670  126.950861
# 1  37.601670  126.950861
# 3  37.485192  127.002220
# 4  37.553414  126.969173
# 5  37.560546  127.022122

# %%
g_map = g.Map(location =[37.60167,126.950861],zoom_start = 12)

# %%
# 앞서 구한 위도와 경도 정보를 가지고 실제 위치에 찍은 결과

for item in child.index:
    lat = child.loc[item, '위도']
    long = child.loc[item, '경도']
    g.Marker([lat, long],
                        fill = True).add_to(g_map)
g_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_80b2bdba059eb1a48e61c87f6abc756d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_80b2bdba059eb1a48e61c87f6abc756d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_80b2bdba059eb1a48e61c87f6abc756d = L.map(
#                 &quot;map_80b2bdba059eb1a48e61c87f6abc756d&quot;,
#                 {
#                     center: [37.60167, 126.950861],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_56246d216d607963a55463defb328692 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_80b2bdba059eb1a48e61c87f6abc756d);
#
#
#             var marker_8867c60ee380c3e165c9b9e6a89503ac = L.marker(
#                 [37.6016701999992, 126.950860779037],
#                 {&quot;fill&quot;: true}
#             ).addTo(map_80b2bdba059eb1a48e61c87f6abc756d);
#
#
#             var marker_b7568b76e5de303cb2602d4e7eab4a72 = L.marker(
#                 [37.6016701999992, 126.950860779037],
#                 {&quot;fill&quot;: true}
#             ).addTo(map_80b2bdba059eb1a48e61c87f6abc756d);
#
#
#             var marker_5279c0c846bce9935da65043af7f4c5a = L.marker(
#                 [37.4851924892032, 127.00222023017],
#                 {&quot;fill&quot;: true}
#             ).addTo(map_80b2bdba059eb1a48e61c87f6abc756d);
#
#
#             var marker_747af60c1b55d0d2d871324d73744e11 = L.marker(
#                 [37.5534136999995, 126.969173179038],
#                 {&quot;fill&quot;: true}
#             ).addTo(map_80b2bdba059eb1a48e61c87f6abc756d);
#
#
#             var marker_3c89a3fe13f3cd99d62697003c43fe30 = L.marker(
#                 [37.5605461000006, 127.022121779038],
#                 {&quot;fill&quot;: true}
#             ).addTo(map_80b2bdba059eb1a48e61c87f6abc756d);
#
#
#             var marker_ae434cff2e3444ce893e85448f5e29cf = L.marker(
#                 [37.6429261404805, 126.898945779037],
#                 {&quot;fill&quot;: true}
#             ).addTo(map_80b2bdba059eb1a48e61c87f6abc756d);
#
#
#             var marker_ef80642c40ff5fe33b740b640135d153 = L.marker(
#                 [37.6056469032544, 126.906342555227],
#                 {&quot;fill&quot;: true}
#             ).addTo(map_80b2bdba059eb1a48e61c87f6abc756d);
#
#
#             var marker_8e25ab4a0d10627bd1d5a448f6c45035 = L.marker(
#                 [37.59900316442855, 126.928741929618],
#                 {&quot;fill&quot;: true}
#             ).addTo(map_80b2bdba059eb1a48e61c87f6abc756d);
#
#
#             var marker_36820f5bb06afe656793f9d490ef8c23 = L.marker(
#                 [37.59769339914176, 126.92951826917286],
#                 {&quot;fill&quot;: true}
#             ).addTo(map_80b2bdba059eb1a48e61c87f6abc756d);
#
#
#             var marker_dbe5736f47626d66499ab86955ccb348 = L.marker(
#                 [37.59806292003524, 126.92971042496258],
#                 {&quot;fill&quot;: true}
#             ).addTo(map_80b2bdba059eb1a48e61c87f6abc756d);
#
#
#             var marker_8e750069a89d25b561001648a61bfa8a = L.marker(
#                 [37.5844698741176, 126.939018571348],
#                 {&quot;fill&quot;: true}
#             ).addTo(map_80b2bdba059eb1a48e61c87f6abc756d);
#
#
#             var marker_42acfb206ebb6516ea3db7ad4cd1f21c = L.marker(
#                 [37.5682043607912, 126.959453032681],
#                 {&quot;fill&quot;: true}
#             ).addTo(map_80b2bdba059eb1a48e61c87f6abc756d);
#
#
#             var marker_3d069eced6e678c3d336b97265ec4094 = L.marker(
#                 [37.58077404066173, 126.87846728034332],
#                 {&quot;fill&quot;: true}
#             ).addTo(map_80b2bdba059eb1a48e61c87f6abc756d);
#
#
#             var marker_f612e013ceaa18d7ddb093c2fc7ec651 = L.marker(
#                 [37.5306478409012, 126.826623748431],
#                 {&quot;fill&quot;: true}
#             ).addTo(map_80b2bdba059eb1a48e61c87f6abc756d);
#
#
#             var marker_60927c78eed8e2cf20fd94dbde1a8c90 = L.marker(
#                 [37.58425273211787, 126.8120995722167],
#                 {&quot;fill&quot;: true}
#             ).addTo(map_80b2bdba059eb1a48e61c87f6abc756d);
#
#
#             var marker_e5d878e3a8a2dbe8706daa82ec5b10fd = L.marker(
#                 [37.4812508584367, 126.837942428298],
#                 {&quot;fill&quot;: true}
#             ).addTo(map_80b2bdba059eb1a48e61c87f6abc756d);
#
#
#             var marker_6e884a324d8c43726e0fd150f8c35195 = L.marker(
#                 [37.4923751941495, 126.844756449835],
#                 {&quot;fill&quot;: true}
#             ).addTo(map_80b2bdba059eb1a48e61c87f6abc756d);
#
#
#             var marker_0f8780a18a248513818b7b0b947d9f57 = L.marker(
#                 [37.4521934714906, 126.913172084259],
#                 {&quot;fill&quot;: true}
#             ).addTo(map_80b2bdba059e

# %% [markdown]
# ## 버스 정류장 / 보건시설

# %%
from dbfread import DBF
bus = DBF('data/bus/TB_E_BUSSTOP_2019.dbf')
bus = pd.DataFrame(bus)

TBVIATR = DBF("data/집객시설/TL_TBVIATR_FCLTY_INFO_2019.dbf")
TBVIATR = pd.DataFrame(TBVIATR)

# %%
#병원 데이터가 어디 들어가는지 확인 -> 보건시설 !!
TBVIATR['MLSFCDC'].value_counts()
# Out:
# 교육시설        6616
# 보건시설        6552
# 서비스산업       2869
# 숙박시설        2485
# 문화/예술시설      525
# 지방행정기관       460
# 정치/사회/외교     117
# 교통시설         108
# 중앙행정기관        50
# Name: MLSFCDC, dtype: int64

# %%
health = TBVIATR[TBVIATR['MLSFCDC'].str.contains('보건시설', na=False)].reset_index(drop=True)
health.head(5)
# Out:
#   STDR_YM VIAT_SE_CD VIAT_CD          VIAT_ID LCLASDC MLSFCDC SCLASDC DCLASDC  \
# 0              30205    0102  AA0000000008102   교육/보건    보건시설  기타보건시설      약국
# 1              30204    0000    AA00000000410   교육/보건    보건시설     한의원
# 2              30205    0100  AA0000000042100   교육/보건    보건시설  기타보건시설      약국
# 3              30205    0100  AA0000000047100   교육/보건    보건시설  기타보건시설      약국
# 4              30205    0100  AA0000000055100   교육/보건    보건시설  기타보건시설      약국
#
#   BCLASDC   VIAT_NM ADRES_CD ADRES_NM TELNO      X_VALUE      Y_VALUE  \
# 0     메디팜  (주)그린메디팜                          202921.6973  553258.6720
# 1           100년한의원                          197670.4869  551416.0771
# 2     미분류    100세약국                          191493.2440  548198.3160
# 3     미분류     123약국                          192263.7666  545770.3567
# 4     미분류   21C혜민약국                          195272.3261  548808.2408
#
#   ADRES_SP BLCK_CD REGIST_DE ERSR_DE REGIST_DT
# 0
# 1
# 2
# 3
# 4

# %%
# 필요한 컬럼만 뽑아오기
health = health[['MLSFCDC', 'DCLASDC', 'VIAT_NM', 'X_VALUE', 'Y_VALUE']]
health
# Out:
#      MLSFCDC DCLASDC      VIAT_NM      X_VALUE      Y_VALUE
# 0       보건시설      약국     (주)그린메디팜  202921.6973  553258.6720
# 1       보건시설              100년한의원  197670.4869  551416.0771
# 2       보건시설      약국       100세약국  191493.2440  548198.3160
# 3       보건시설      약국        123약국  192263.7666  545770.3567
# 4       보건시설      약국      21C혜민약국  195272.3261  548808.2408
# ...      ...     ...          ...          ...          ...
# 6547    보건시설          힐탑빌딩아침나라한의원  203904.6680  547321.5820
# 6548    보건시설     미분류         힘찬병원  202946.8961  560671.9543
# 6549    보건시설     미분류         힘찬병원  209710.1690  545367.4769
# 6550    보건시설      약국         힘찬약국  200996.7845  556280.0200
# 6551    보건시설     미분류   힝복한반려동물의료원  198202.5075  542818.3573
#
# [6552 rows x 5 columns]

# %%
#보건시설의 x, y 축 좌표만 추출
health_xy = health[["X_VALUE", "Y_VALUE"]]
health_xy.head(5)
# Out:
#        X_VALUE      Y_VALUE
# 0  202921.6973  553258.6720
# 1  197670.4869  551416.0771
# 2  191493.2440  548198.3160
# 3  192263.7666  545770.3567
# 4  195272.3261  548808.2408

# %%
coord = np.array(health_xy)

# %%
# TM -> 위경도 변환 함수

def project_array(coord, p1_type, p2_type):
    """
    좌표계 변환 함수
    - coord: x, y 좌표 정보가 담긴 NumPy Array
    - p1_type: 입력 좌표계 정보 ex) epsg:5186
    - p2_type: 출력 좌표계 정보 ex) epsg:4326
    """
    p1 = pyproj.Proj(init=p1_type)
    p2 = pyproj.Proj(init=p2_type)
    fx, fy = pyproj.transform(p1, p2, coord[:, 0], coord[:, 1])
    return np.dstack([fx, fy])[0]

# %%
# 좌표계 정보 설정
p1_type = "epsg:5186"
p2_type = "epsg:4326"

# project_array() 함수 실행
result_imt = project_array(coord, p1_type, p2_type)
result_imt[:5]
# Out:
# array([[127.03307619,  37.57887386],
#        [126.97363371,  37.56227385],
#        [126.90375474,  37.53324559],
#        [126.91249796,  37.51137642],
#        [126.94650725,  37.53876812]])

# %%
health["위도"] = result_imt[:, 1]
health["경도"] = result_imt[:, 0]

# %%
#위도, 경도로 바꿔주어 새 컬럼값으로 넣어줌
health
# Out:
#      MLSFCDC DCLASDC      VIAT_NM      X_VALUE      Y_VALUE         위도  \
# 0       보건시설      약국     (주)그린메디팜  202921.6973  553258.6720  37.578874
# 1       보건시설              100년한의원  197670.4869  551416.0771  37.562274
# 2       보건시설      약국       100세약국  191493.2440  548198.3160  37.533246
# 3       보건시설      약국        123약국  192263.7666  545770.3567  37.511376
# 4       보건시설      약국      21C혜민약국  195272.3261  548808.2408  37.538768
# ...      ...     ...          ...          ...          ...        ...
# 6547    보건시설          힐탑빌딩아침나라한의원  203904.6680  547321.5820  37.525377
# 6548    보건시설     미분류         힘찬병원  202946.8961  560671.9543  37.645667
# 6549    보건시설     미분류         힘찬병원  209710.1690  545367.4769  37.507728
# 6550    보건시설      약국         힘찬약국  200996.7845  556280.0200  37.606100
# 6551    보건시설     미분류   힝복한반려동물의료원  198202.5075  542818.3573  37.484809
#
#               경도
# 0     127.033076
# 1     126.973634
# 2     126.903755
# 3     126.912498
# 4     126.946507
# ...          ...
# 6547  127.044173
# 6548  127.033391
# 6549  127.109823
# 6550  127.011289
# 6551  126.979676
#
# [6552 rows x 7 columns]

# %%
# 전처리 끝
health = health[['MLSFCDC', 'DCLASDC', 'VIAT_NM', '위도', '경도']]
health
# Out:
#      MLSFCDC DCLASDC      VIAT_NM         위도          경도
# 0       보건시설      약국     (주)그린메디팜  37.578874  127.033076
# 1       보건시설              100년한의원  37.562274  126.973634
# 2       보건시설      약국       100세약국  37.533246  126.903755
# 3       보건시설      약국        123약국  37.511376  126.912498
# 4       보건시설      약국      21C혜민약국  37.538768  126.946507
# ...      ...     ...          ...        ...         ...
# 6547    보건시설          힐탑빌딩아침나라한의원  37.525377  127.044173
# 6548    보건시설     미분류         힘찬병원  37.645667  127.033391
# 6549    보건시설     미분류         힘찬병원  37.507728  127.109823
# 6550    보건시설      약국         힘찬약국  37.606100  127.011289
# 6551    보건시설     미분류   힝복한반려동물의료원  37.484809  126.979676
#
# [6552 rows x 5 columns]

# %%
# 전처리 완료한 데이터 다운로드
health.to_csv("보건시설.csv")

# %% [markdown]
# ## 버스 정류장

# %%
bus.head(5)
# Out:
#      ID    STN_IDN TGRP_CODE         STN_NM    US_YY_DD           TM_X  \
# 0  4799  100000001        버스        종로2가사거리  2019-07-30  198920.990795
# 1   110  100000002        버스    창경궁.서울대학교병원  2019-07-30  199692.618782
# 2   109  100000003        버스      명륜3가.성대입구  2019-07-30  199848.973782
# 3  4796  100000004        버스       종로2가.삼일교  2019-07-30  198896.329903
# 4   108  100000005        버스  혜화동로터리.여운형활동터  2019-07-30  200149.651139
#
#             TM_Y STTN_ARSNO
# 0  552247.155925      01001
# 1  553292.015192      01002
# 2  553683.796125      01003
# 3  552115.980102      01004
# 4  554074.605152      01005

# %%
bus_xy = bus[["TM_X", "TM_Y"]]
bus_xy.head(5)
# Out:
#             TM_X           TM_Y
# 0  198920.990795  552247.155925
# 1  199692.618782  553292.015192
# 2  199848.973782  553683.796125
# 3  198896.329903  552115.980102
# 4  200149.651139  554074.605152

# %%
coord = np.array(bus_xy)

# 좌표계 정보 설정
p1_type = "epsg:5186"
p2_type = "epsg:4326"

# project_array() 함수 실행
result_imt = project_array(coord, p1_type, p2_type)

# %%
bus["위도"] = result_imt[:, 1]
bus["경도"] = result_imt[:, 0]

# %%
result_sub = np.array(child[['위도', '경도']])
bus_spare = np.array(bus[['위도', '경도']])
bus_spare
# Out:
# array([[ 37.56976415, 126.98778615],
#        [ 37.57917886, 126.99652016],
#        [ 37.58270882, 126.99829016],
#        ...,
#        [ 37.53368604, 127.12347693],
#        [ 37.5361987 , 127.12540981],
#        [ 37.5403901 , 127.12735353]])

# %%
bus["위도"] = result_imt[:, 1]
bus["경도"] = result_imt[:, 0]

# %%
bus = bus[['STN_NM', '위도', '경도']]

# %%
bus
# Out:
#               STN_NM         위도          경도
# 0            종로2가사거리  37.569764  126.987786
# 1        창경궁.서울대학교병원  37.579179  126.996520
# 2          명륜3가.성대입구  37.582709  126.998290
# 3           종로2가.삼일교  37.568582  126.987507
# 4      혜화동로터리.여운형활동터  37.586230  127.001694
# ...              ...        ...         ...
# 11175          우성아파트  37.550442  127.139326
# 11176          우성아파트  37.550620  127.140052
# 11177           조일약국  37.533686  127.123477
# 11178           성내시장  37.536199  127.125410
# 11179    천호우체국.로데오거리  37.540390  127.127354
#
# [11180 rows x 3 columns]

# %%
# 전처리 완료한 데이터 다운로드
#bus.to_csv("버스정류장.csv")

# %% [markdown]
# ## 착한가격업소

# %%
kind = pd.read_excel("data/착한업소크롤링.xlsx")
kind
# Out:
#       구      업종        업소명         주요품목      가격            연락처  \
# 0    강남   한식_육류  미테리언육식주의자  와규꽃등심(150g)  21000원    02-566-2238
# 1    강남   한식_일반       만나식당           백반   5000원    02-451-8886
# 2    강남      일식        돈바치           우동   4500원  070-7778-8300
# 3    강남   한식_분식       대청분식         어묵우동   5000원   02-2226-2928
# 4    강남   한식_면류    다시사랑한다면         잔치국수   4500원    02-555-0451
# ..   ..     ...        ...          ...     ...            ...
# 721  중랑    이미용업   아폴로헤어크리닉      미용료(파마)  27000원    02-495-7337
# 722  중랑  기타서비스업       포토아트        사진촬영료  10000원    02-435-1757
# 723  중랑    이미용업      더 이등병      이용료(커트)   6000원   02-2208-5513
# 724  중랑    이미용업     상록수미용실      미용료(파마)  15000원  010-8823-3600
# 725  중랑    이미용업     강헤어컬렉션      미용료(파마)  25000원   02-2208-4790
#
#                                 주소
# 0            서울특별시 강남구 강남구 역삼로8길 5
# 1    서울특별시 강남구 강남구 개포로 109길 5 106호
# 2       서울특별시 강남구 강남구 개포로 250 103호
# 3      서울특별시 강남구 강남구 개포로 621 B102호
# 4            서울특별시 강남구 강남구 언주로 407
# ..                             ...
# 721           서울특별시 중랑구 사가정로50길 67
# 722            서울특별시 중랑구 면목로40길 16
# 723            서울특별시 중랑구 면목로33길 33
# 724            서울특별시 중랑구 동일로99길 22
# 725              서울특별시 중랑구 면목로 430
#
# [726 rows x 7 columns]

# %%
# 데이터프레임 주소값 추출
address= kind['주소']
print(address.head())
# Out:
# 0            서울특별시 강남구 강남구 역삼로8길 5
# 1    서울특별시 강남구 강남구 개포로 109길 5 106호
# 2       서울특별시 강남구 강남구 개포로 250 103호
# 3      서울특별시 강남구 강남구 개포로 621 B102호
# 4            서울특별시 강남구 강남구 언주로 407
# Name: 주소, dtype: object

# %%
# 주소 데이터 깔끔하게 다듬기
for i in range(len(address)):
    a = address[i].split(' ')
    address[i] = " ".join(a[0:2])
print(address.head())
# Out:
# 0    서울특별시 강남구 강남구 역삼로8길
# 1      서울특별시 강남구 강남구 개포로
# 2      서울특별시 강남구 강남구 개포로
# 3      서울특별시 강남구 강남구 개포로
# 4      서울특별시 강남구 강남구 언주로
# Name: 주소, dtype: object

# %%
####### 도로명주소 위도 경도 값으로 바꿔주기 ########
#from geopy.geocoders import Nominatim
#geo_local = Nominatim(user_agent='South Korea')

# 위도, 경도 반환하는 함수
#def geocoding(address):
#    try:
#        geo = geo_local.geocode(address)
#        x_y = [geo.latitude, geo.longitude]
#        return x_y

#    except:
#        return [0,0]

# %%
#####주소를 위,경도 값으로 변환하기 #####
#latitude = []
#longitude =[]

#for i in address:
#    latitude.append(geocoding(i)[0])
#    longitude.append(geocoding(i)[1])

# %%
#####Dataframe만들기######
#address_df = pd.DataFrame({'업소명': kind['업소명'],'주소':kind['주소'],'주소':address,'위도':latitude,'경도':longitude})

# %%
#df저장
#address_df.to_csv('착한가격업소.csv')

# %% [markdown]
# ## 도서관

# %%
from dbfread import DBF
library = DBF('data/도서관/TL_LBRRY_2019.dbf')
library = pd.DataFrame(library)

# %%
library
# Out:
#      LBRRY_ID         LBRRY_NM SIG_NM                                 ADRES  \
# 0        1935        강남구립못골도서관    강남구                       서울시 강남구 자곡로 116
# 1        1066       강남역삼푸른솔도서관    강남구               서울특별시 강남구 테헤란로8길 36. 4층
# 2           3      국립어린이청소년도서관    강남구                   서울특별시 강남구 테헤란로7길 21
# 3          48            논현도서관    강남구         서울 강남구 학동로 북32길 17 논현2문화센터 6층
# 4          49            대치도서관    강남구  서울특별시 강남구 삼성로 212 은마아파트 복지상가 2층 215호
# ...       ...              ...    ...                                   ...
# 1219      870  영광시각장애인모바일점자도서관   서대문구             서울특별시 서대문구 세검정로 78-19, 2층
# 1220      871          성북점자도서관    성북구                 서울특별시 성북구 동소문로25가길 20
# 1221       75    송파시각장애인정보문화센터    송파구                   서울특별시 송파구 마천로61길 26
# 1222      873        한국학생점자도서관    종로구                  서울특별시 종로구 자하문로 131-1
# 1223       68         종달새전화도서관     중구                    서울특별시 중구 을지로22길 19
#
#                            TELNO         FXNUM  \
# 0                    02-459-5522
# 1                   02-2051-1178  02-2051-1178
# 2                   02-3413-4800  02-3451-0724
# 3                   02-3443-7650   02-542-6459
# 4                    02-565-6666   02-554-6666
# ...                          ...           ...
# 1219                 02-393-4568   02-392-1136
# 1220  02) 923-4555 (내선 222, 223)  02) 928-6565
# 1221                 02-422-6070   02-422-6117
# 1222                 02-880-0610
# 1223                 02-736-3000
#
#                                                HMPG  \
# 0                        http://mglib.gangnam.go.kr
# 1                      http://ysplib.gangnam.go.kr/
# 2                            http://www.nlcy.go.kr/
# 3                       http://nhlib.gangnam.go.kr/
# 4                      http://dchlib.gangnam.go.kr/
# ...                                             ...
# 1219                          http://ygculture.com/
# 1220                                      sorym.org
# 1221                       http://hotlineworld.net/
# 1222  http://dream.nl.go.kr/hosting/311091/index.do
# 1223
#
#                      CLOSE_DATE LBRRY_SE OPNNG_DATE           tm_x  \
# 0                    둘째, 넷째 화요일    공공도서관             208544.998827
# 1            2,4 주 화요일 및 법정 공휴일    공공도서관   20090612  202833.823508
# 2     매월 둘째넷째 월요일, 일요일을 제외한 공휴일    공공도서관   20060628  202625.580690
# 3                   매월 2,4주 화요일    공공도서관   19970910  203290.708750
# 4           매월 2,4주 화요일 및 법정공휴일    공공도서관   19990226  205678.330625
# ...                         ...      ...        ...            ...
# 1219                         없음   장애인도서관   20110315  195499.703955
# 1220                 주말 및 국정공휴일   장애인도서관   20110501  201700.035838
# 1221                       국공휴일   장애인도서관   20000914  213724.224313
# 1222                    토,일,공휴일   장애인도서관   20091211  197272.249964
# 1223                         없음   장애인도서관   19940207  199656.140223
#
#                tm_y
# 0     541350.373971
# 1     544116.641606
# 2     544605.442417
# 3     546423.459127
# 4     543988.129931
# ...             ...
# 1219  555070.300083
# 1220  555092.436630
# 1221  543838.645871
# 1222  554209.898266
# 1223  551780.768979
#
# [1224 rows x 12 columns]

# %%
# 필요한 컬럼만 뽑아오기
library = library[['LBRRY_NM', 'SIG_NM', 'tm_x', 'tm_y']]
library
# Out:
#              LBRRY_NM SIG_NM           tm_x           tm_y
# 0           강남구립못골도서관    강남구  208544.998827  541350.373971
# 1          강남역삼푸른솔도서관    강남구  202833.823508  544116.641606
# 2         국립어린이청소년도서관    강남구  202625.580690  544605.442417
# 3               논현도서관    강남구  203290.708750  546423.459127
# 4               대치도서관    강남구  205678.330625  543988.129931
# ...               ...    ...            ...            ...
# 1219  영광시각장애인모바일점자도서관   서대문구  195499.703955  555070.300083
# 1220          성북점자도서관    성북구  201700.035838  555092.436630
# 1221    송파시각장애인정보문화센터    송파구  213724.224313  543838.645871
# 1222        한국학생점자도서관    종로구  197272.249964  554209.898266
# 1223         종달새전화도서관     중구  199656.140223  551780.768979
#
# [1224 rows x 4 columns]

# %%
library_xy = library[["tm_x", "tm_y"]]
library_xy.head(5)
# Out:
#             tm_x           tm_y
# 0  208544.998827  541350.373971
# 1  202833.823508  544116.641606
# 2  202625.580690  544605.442417
# 3  203290.708750  546423.459127
# 4  205678.330625  543988.129931

# %%
coord = np.array(library_xy)

# TM -> 위경도 변환 함수

def project_array(coord, p1_type, p2_type):
    """
    좌표계 변환 함수
    - coord: x, y 좌표 정보가 담긴 NumPy Array
    - p1_type: 입력 좌표계 정보 ex) epsg:5186
    - p2_type: 출력 좌표계 정보 ex) epsg:4326
    """
    p1 = pyproj.Proj(init=p1_type)
    p2 = pyproj.Proj(init=p2_type)
    fx, fy = pyproj.transform(p1, p2, coord[:, 0], coord[:, 1])
    return np.dstack([fx, fy])[0]

# %%
# 좌표계 정보 설정
p1_type = "epsg:5186"
p2_type = "epsg:4326"

# project_array() 함수 실행
result_imt = project_array(coord, p1_type, p2_type)
result_imt[:5]
# Out:
# array([[127.09659841,  37.47154497],
#        [127.03204611,  37.49650442],
#        [127.02969295,  37.50090916],
#        [127.03722308,  37.51728744],
#        [127.06421203,  37.49533341]])

# %%
library_xy["위도"] = result_imt[:, 1]
library_xy["경도"] = result_imt[:, 0]

# %%
#위도, 경도로 바꿔주어 새 컬럼값으로 넣어줌
library_xy

library_xy = np.array(library_xy[['위도', '경도']])
library_xy
# Out:
# array([[ 37.47154497, 127.09659841],
#        [ 37.49650442, 127.03204611],
#        [ 37.50090916, 127.02969295],
#        ...,
#        [ 37.49390207, 127.15519406],
#        [ 37.58744494, 126.96911593],
#        [ 37.56556259, 126.9961079 ]])

# %%
# 바꾼 위경도 새 컬럼으로 넣어주기
library["위도"] = result_imt[:, 1]
library["경도"] = result_imt[:, 0]
library
# Out:
#              LBRRY_NM SIG_NM           tm_x           tm_y         위도  \
# 0           강남구립못골도서관    강남구  208544.998827  541350.373971  37.471545
# 1          강남역삼푸른솔도서관    강남구  202833.823508  544116.641606  37.496504
# 2         국립어린이청소년도서관    강남구  202625.580690  544605.442417  37.500909
# 3               논현도서관    강남구  203290.708750  546423.459127  37.517287
# 4               대치도서관    강남구  205678.330625  543988.129931  37.495333
# ...               ...    ...            ...            ...        ...
# 1219  영광시각장애인모바일점자도서관   서대문구  195499.703955  555070.300083  37.595190
# 1220          성북점자도서관    성북구  201700.035838  555092.436630  37.595399
# 1221    송파시각장애인정보문화센터    송파구  213724.224313  543838.645871  37.493902
# 1222        한국학생점자도서관    종로구  197272.249964  554209.898266  37.587445
# 1223         종달새전화도서관     중구  199656.140223  551780.768979  37.565563
#
#               경도
# 0     127.096598
# 1     127.032046
# 2     127.029693
# 3     127.037223
# 4     127.064212
# ...          ...
# 1219  126.949042
# 1220  127.019250
# 1221  127.155194
# 1222  126.969116
# 1223  126.996108
#
# [1224 rows x 6 columns]

# %%
# 전처리 끝
library = library[['LBRRY_NM', 'SIG_NM', '위도', '경도']]
library
# Out:
#              LBRRY_NM SIG_NM         위도          경도
# 0           강남구립못골도서관    강남구  37.471545  127.096598
# 1          강남역삼푸른솔도서관    강남구  37.496504  127.032046
# 2         국립어린이청소년도서관    강남구  37.500909  127.029693
# 3               논현도서관    강남구  37.517287  127.037223
# 4               대치도서관    강남구  37.495333  127.064212
# ...               ...    ...        ...         ...
# 1219  영광시각장애인모바일점자도서관   서대문구  37.595190  126.949042
# 1220          성북점자도서관    성북구  37.595399  127.019250
# 1221    송파시각장애인정보문화센터    송파구  37.493902  127.155194
# 1222        한국학생점자도서관    종로구  37.587445  126.969116
# 1223         종달새전화도서관     중구  37.565563  126.996108
#
# [1224 rows x 4 columns]

# %%
# 전처리 완료한 데이터 다운로드
#library.to_csv("도서관.csv")

# %% [markdown]
# ## 전월세

# %%
pd.set_option('display.max_row', 500)
pd.set_option('display.max_columns', 100)

# %%
df = pd.read_csv("data/전월세/서울특별시_전월세가_2021.txt", sep=',', encoding='cp949')
df
# Out:
#         접수년도  자치구코드 자치구명  법정동코드   법정동명  지번구분코드 지번구분      본번    부번    층  \
# 0       2021  11170  용산구  11300  원효로2가     1.0   대지     1.0   0.0  6.0
# 1       2021  11170  용산구  11300  원효로2가     1.0   대지     1.0   0.0  6.0
# 2       2021  11440  마포구  11000   노고산동     1.0   대지     1.0   1.0  5.0
# 3       2021  11440  마포구  11000   노고산동     1.0   대지     1.0   1.0  9.0
# 4       2021  11545  금천구  10200    독산동     1.0   대지  1006.0  54.0  2.0
# ...      ...    ...  ...    ...    ...     ...  ...     ...   ...  ...
# 524670  2021  11305  강북구  10100    미아동     NaN  NaN     NaN   NaN  NaN
# 524671  2021  11260  중랑구  10400     묵동     NaN  NaN     NaN   NaN  NaN
# 524672  2021  11590  동작구  10700    사당동     NaN  NaN     NaN   NaN  NaN
# 524673  2021  11620  관악구  10200    신림동     NaN  NaN     NaN   NaN  NaN
# 524674  2021  11305  강북구  10300    수유동     NaN  NaN     NaN   NaN  NaN
#
#              계약일 전월세구분    임대면적  보증금(만원)  임대료(만원)            건물명    건축년도  \
# 0       20210317    월세   21.45      500       33        \t(1)\t  1990.0
# 1       20210406    전세   21.45    12000        0        \t(1)\t  1990.0
# 2       20201202    월세   33.66    10000       55      \t(1-1)\t  1998.0
# 3       20210201    전세   33.66    11000        0      \t(1-1)\t  1998.0
# 4       20210302    월세   17.67      500       50  \t(1006-54)\t  2014.0
# ...          ...   ...     ...      ...      ...            ...     ...
# 524670  20210731    월세  249.00     4000      120            NaN  1970.0
# 524671  20210614    전세  249.67    17000        0            NaN  2019.0
# 524672  20210701    월세  249.67     5000       60            NaN     NaN
# 524673  20211129    전세  249.69    26000        0            NaN  1987.0
# 524674  20211008    전세  249.84    70000        0            NaN  1988.0
#
#          건물용도         계약기간 신규계약구분 갱신청구권사용  종전보증금  종전임대료
# 0        오피스텔          NaN    NaN     NaN    NaN    NaN
# 1        오피스텔          NaN    NaN     NaN    NaN    NaN
# 2        오피스텔          NaN    NaN     NaN    NaN    NaN
# 3        오피스텔          NaN    NaN     NaN    NaN    NaN
# 4        오피스텔          NaN    NaN     NaN    NaN    NaN
# ...       ...          ...    ...     ...    ...    ...
# 524670  단독다가구  21.07~23.07     신규     NaN    NaN    NaN
# 524671  단독다가구  21.07~23.07     신규     NaN    NaN    NaN
# 524672  단독다가구          NaN    NaN     NaN    NaN    NaN
# 524673  단독다가구          NaN    NaN     NaN    NaN    NaN
# 524674  단독다가구  21.11~23.11     신규     NaN    NaN    NaN
#
# [524675 rows x 23 columns]

# %%
df = df[['자치구코드', '자치구명', '법정동코드', '법정동명', '전월세구분', '보증금(만원)', '임대료(만원)']]
df
# Out:
#         자치구코드 자치구명  법정동코드   법정동명 전월세구분  보증금(만원)  임대료(만원)
# 0       11170  용산구  11300  원효로2가    월세      500       33
# 1       11170  용산구  11300  원효로2가    전세    12000        0
# 2       11440  마포구  11000   노고산동    월세    10000       55
# 3       11440  마포구  11000   노고산동    전세    11000        0
# 4       11545  금천구  10200    독산동    월세      500       50
# ...       ...  ...    ...    ...   ...      ...      ...
# 524670  11305  강북구  10100    미아동    월세     4000      120
# 524671  11260  중랑구  10400     묵동    전세    17000        0
# 524672  11590  동작구  10700    사당동    월세     5000       60
# 524673  11620  관악구  10200    신림동    전세    26000        0
# 524674  11305  강북구  10300    수유동    전세    70000        0
#
# [524675 rows x 7 columns]

# %%
# 전처리 완료
#df.to_csv('전월세.csv')

# %% [markdown]
# ## 물가

# %%
import re
a = pd.read_excel("data/서울시 대형마트.xlsx")
b = pd.read_excel("data/서울시 전통시장물가.xlsx")

# %%
for i in range(len(a)):
  a["품목"][i] = re.sub('\([^)]*\)',"", a["품목"][i]) # 괄호 안 내용 제거
a = a.iloc[:,[0,2,5]]
a.head()
# Out:
#    품목      가격   구
# 0  사과  1245.0  용산
# 1   배  2725.0  용산
# 2  배추  7480.0  용산
# 3   무  3100.0  용산
# 4  양파  4150.0  용산

# %%
for i in range(len(b)):
  b["품목"][i] = re.sub('\([^)]*\)',"", b["품목"][i])
b = b.iloc[:,[0,2,5]]
b.head()
# Out:
#    품목     가격   구
# 0  사과   2000  종로
# 1   배   4000  종로
# 2  배추  12000  종로
# 3   무   4000  종로
# 4  양파   4500  종로

# %%
ab = a.merge(b, on=['품목','구'], how='left') # 병합 
ab.rename(columns = {'가격_x':'가격_대형마트','가격_y':'가격_전통시장'},inplace=True) # 속성이름변경
ab = ab[['구','품목','가격_대형마트','가격_전통시장']] # 속성재배치
ab
# Out:
#       구   품목  가격_대형마트  가격_전통시장
# 0    용산   사과   1245.0   1500.0
# 1    용산    배   2725.0   3000.0
# 2    용산   배추   7480.0  10000.0
# 3    용산    무   3100.0   4000.0
# 4    용산   양파   4150.0   3500.0
# ..   ..  ...      ...      ...
# 777  동작   달걀   6480.0   7000.0
# 778  동작   조기   2880.0   2000.0
# 779  동작   명태   5980.0   3000.0
# 780  동작  오징어   3780.0   4000.0
# 781  동작  고등어   2990.0   3000.0
#
# [782 rows x 4 columns]

# %%
# 전처리 완료한 데이터 다운로드
#ab.to_csv("물가.csv")
